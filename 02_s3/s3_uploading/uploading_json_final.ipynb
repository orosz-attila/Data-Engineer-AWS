# %%
# Importing Library
import logging
import boto3
from botocore.exceptions import ClientError
import os
PATH = os.path.abspath('')
from posixpath import dirname
import cv2
import io
import pandas as pd
import numpy as np
import json

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('module1iot')
subfolder_path = 'attila/images/'

# %% [markdown]
# ### 1. Extract the object ID from the image name (Die Objekt-ID aus dem Bild-Namen extrahieren)

# %%
def extract_objectID(subfolder_path):
    list = []
    for object in bucket.objects.filter(Prefix=f'{subfolder_path}'):
        file_name = object.key.split('/')[-1]
        objectID = file_name.split('.')[0]   
        list.append(objectID)
    return list

# %%
list_objectID = extract_objectID('attila/images/')

# %%
list_objectID
# Out:
# ['005615461175',
#  '01B2298F399B',
#  '01EE25AE7570',
#  '032ED1597043',
#  '039BD2480D54',
#  '046A137A7CE4',
#  '06E91D2C64E2',
#  '09C19D2D6A9A',
#  '0A6390C43EEF',
#  '0ADFA616B188',
#  '123E58CFB326',
#  '132B6D657FC4',
#  '13BDB60CD560',
#  '191E0E80E332',
#  '1ACA78EBBDBA',
#  '1B933CD30744',
#  '1F777929DCEE',
#  '2001AAE1304E',
#  '22CEA0A3897A',
#  '2B7207BEEC7E',
#  '2BC04C4C0E0B',
#  '2BE61A6116BF',
#  '30307F1D46A5',
#  '30FC914E2A05',
#  '3375822487DE',
#  '355F36B79EEF',
#  '359E8E1D83D7',
#  '36212FCA314A',
#  '363152CAB374',
#  '380B1A6047A3',
#  '386F626832BC',
#  '38BEDA88018E',
#  '3C638952712F',
#  '3E6788274CA7',
#  '3EB434D60438',
#  '3F130B93EF80',
#  '3F630C84A097',
#  '465010534D11',
#  '471A9998B336',
#  '4A39AE3C31C1',
#  '4AD1223F8D31',
#  '4F13406C0117',
#  '52F4FBC55FF7',
#  '536E8D996584',
#  '579A509C3482',
#  '5B124CDBB2CF',
#  '5D5637D229F1',
#  '5E0EB38E878D',
#  '5EA599392ED7',
#  '5EB21C03C280',
#  '5EEA6BBC8E2F',
#  '5F37783C7829',
#  '5FF46525B2FF',
#  '62543A2F491B',
#  '62DE4ACB6D22',
#  '62E385D68FE5',
#  '63E7A4015CE8',
#  '663CC97386EC',
#  '6F2E8A2541B4',
#  '71A756EE0259',
#  '74C52EBE7FF4',
#  '75626ECE7DF6',
#  '7619058456CE',
#  '76F0ACD35643',
#  '7A19D1DE99D4',
#  '7BC584B680BB',
#  '7EDE36EE6279',
#  '80BC1D2CD729',
#  '8267B0E540D8',
#  '83C81F3AC631',
#  '847A89B77A7C',
#  '848805776E48',
#  '85D0058A60A7',
#  '879ABE530EF7',
#  '884912A8F73B',
#  '892121746937',
#  '89779D1A6581',
#  '8CD18DE4A055',
#  '901A53A42955',
#  '92BB982DBB33',
#  '92D42004DC9A',
#  '93E8EDFBA2C6',
#  '94A29074BD7C',
#  '96DD29B4BE26',
#  '9739760EFEEE',
#  '97CAED4337EC',
#  '99EF08C87DED',
#  '9A915B48B46F',
#  '9EA60DBF2C76',
#  '9F0DBA0B3D38',
#  'A0CE582262F8',
#  'A153E709616B',
#  'A68C526FD6E5',
#  'AB74C0E5FE76',
#  'AC3DEE430115',
#  'AD4C02904D08',
#  'AE45B77C9BBE',
#  'B68B30C88E9C',
#  'BAC84A97F50F',
#  'C059408DB6E5',
#  'C45E6921DB8A',
#  'C53997A863AD',
#  'C6688D71F7CC',
#  'C7FF949E1C4D',
#  'CD65AAA9A176',
#  'CF406E3D8EAE',
#  'CFC275963C32',
#  'D08541080DF7',
#  'D441B2C22775',
#  'D99FE5C7D40C',
#  'DAA839E10C86',
#  'DCAC7AC793FE',
#  'E40DD53CDFEF',
#  'E875E5CDE62E',
#  'E94453D33543',
#  'E98891DFF18E',
#  'EA47152DD993',
#  'EB8A560D2448',
#  'EBEDF5826E26',
#  'EC26A3EB474F',
#  'EDF922608FF1',
#  'EE4DC5CFAFB7',
#  'EF7F589D67AA',
#  'F35019E74631',
#  'F3BA92D52127',
#  'F42F6A89906D',
#  'F641884F8770',
#  'F988BD965071',
#  'FBC9E2D10747',
#  'FEBF0D5D613B']

# %% [markdown]
# ### 2.  Decrypt the QR code ( Den QR-Code entschlüsseln)

# %%
def decode_QRcode(bucket, subfolder_path):
    detector = cv2.QRCodeDetector()
    list = []
    for object in bucket.objects.filter(Prefix=f'{subfolder_path}'):
        img = bucket.Object(object.key).get().get('Body').read()
        img_nparray = cv2.imdecode(np.asarray(bytearray(img)), cv2.IMREAD_COLOR)
        data, vertices_array, binary_qrcode = detector.detectAndDecode(img_nparray)
        list.append(data)
    return list

# %%
list_QRcode_data = decode_QRcode(bucket, subfolder_path)

# %%
list_QRcode_data
# Out:
# ['F0100000717',
#  'F01000C3A8A',
#  'F010008CE62',
#  'F0100081637',
#  'F01000A8EE3',
#  'F01000A53A7',
#  'F01000D17FB',
#  'F0100010C3D',
#  'F0100061471',
#  'F010006D0D8',
#  'F010004964D',
#  'F0100096E01',
#  'F010002596D',
#  'F010009C3F8',
#  'F0100077FEA',
#  'F0100057869',
#  'F010009597E',
#  'F010007CB9E',
#  'F01000B6F04',
#  'F010008B43A',
#  'F01000F5E6A',
#  'F0100085B5C',
#  'F01000B4CC3',
#  'F01000AD3FD',
#  'F0100050864',
#  '',
#  'F01000B6F8F',
#  'F010000EAE3',
#  'F0100030FDA',
#  'F01000DD129',
#  'F010002402E',
#  'F010000A610',
#  'F01000C8D24',
#  'F0100033346',
#  'F0100068CE7',
#  'F01000D62F5',
#  'F01000AE95E',
#  'F01000506F8',
#  'F01000D2DEC',
#  'F0100057F18',
#  'F01000A4FBA',
#  'F01000695C8',
#  'F010000B44B',
#  'F010003EF59',
#  'F0100036FE8',
#  'F0100053FA8',
#  'F0100062665',
#  'F01000A69D5',
#  'F010004BEC0',
#  'F0100050648',
#  'F01000BBBA1',
#  'F010000E9F4',
#  'F0100025B2A',
#  'F0100003331',
#  'F010000F6EE',
#  'F01000708B3',
#  'F010003A191',
#  'F01000F3C8A',
#  'F01000C1A52',
#  'F0100008D47',
#  'F0100033F3C',
#  'F01000057B0',
#  'F01000A9953',
#  'F01000298FE',
#  'F01000495D2',
#  'F01000AF337',
#  'F010005D19D',
#  'F01000C6DD7',
#  'F010004103E',
#  'F01000E4FF7',
#  'F01000C24CB',
#  'F010000E29D',
#  'F01000A2BBF',
#  'F010005DF94',
#  'F01000C7C66',
#  'F0100092C4B',
#  'F01000AA890',
#  'F01000C17F6',
#  'F01000EDE69',
#  'F01000D036A',
#  'F01000683DB',
#  'F0100064942',
#  'F01000ECDE5',
#  'F010005626A',
#  'F010005AECF',
#  'F0100060644',
#  'F0100038729',
#  'F010006FF65',
#  'F01000661C3',
#  'F01000DEE70',
#  'F0100039664',
#  'F01000D5D4C',
#  'F01000E671F',
#  'F01000D8BEF',
#  'F01000244BB',
#  'F0100081702',
#  'F010002FEDD',
#  'F01000646CA',
#  'F01000D1BEB',
#  'F010003C428',
#  'F010008CB80',
#  'F010007F5D4',
#  'F010004ECF4',
#  'F010000815D',
#  'F0100038471',
#  'F01000FE834',
#  'F01000FFC76',
#  'F01000F545F',
#  'F01000C8CF9',
#  'F01000948B0',
#  'F01000F58CA',
#  'F010005AB2B',
#  'F010000508D',
#  'F010001587D',
#  'F010004FD54',
#  'F010006110C',
#  'F0100009671',
#  'F01000ED292',
#  'F01000B372B',
#  'F01000AD233',
#  'F01000DEC70',
#  'F01000E664B',
#  'F01000E321A',
#  'F0100028303',
#  'F01000F8086',
#  'F010001DBFD',
#  'F01000E27F9',
#  'F01000B499C',
#  'F010005E0AB',
#  'F010006AD4B']

# %% [markdown]
# ### 3. Capture a timestamp from the upload (Einen Zeitstempel vom Upload erfassen)

# %%
def get_timestamp(bucket, subfolder_path):
    list = []
    for object in bucket.objects.filter(Prefix=f'{subfolder_path}'):
        list.append(object.last_modified)
    return list

# %%
list_timestamp = get_timestamp(bucket, subfolder_path)

# %%
list_timestamp
# Out:
# [datetime.datetime(2022, 8, 16, 14, 19, 32, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 32, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 33, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 33, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 34, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 34, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 35, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 35, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 35, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 36, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 36, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 37, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 37, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 38, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 38, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 39, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 39, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 40, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 40, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 40, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 41, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 41, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 42, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 42, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 43, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 43, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 44, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 44, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 44, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 14, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 8, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 8, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 8, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 9, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 9, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 10, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 10, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 10, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 11, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 11, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 11, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 12, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 12, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 13, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 13, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 14, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 15, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 23, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 24, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 24, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 25, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 25, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 25, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 26, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 26, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 27, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 27, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 28, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 28, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 28, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 29, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 29, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 29, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 30, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 15, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 45, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 45, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 46, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 47, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 48, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 49, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 49, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 50, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 50, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 51, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 51, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 52, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 52, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 53, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 53, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 54, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 54, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 54, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 55, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 55, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 56, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 56, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 57, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 57, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 58, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 58, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 59, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 19, 59, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 15, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 1, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 1, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 2, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 2, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 3, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 3, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 4, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 4, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 5, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 5, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 6, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 6, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 7, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 7, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 7, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 16, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 16, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 16, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 17, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 17, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 17, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 18, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 18, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 19, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 19, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 20, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 20, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 20, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 21, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 21, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 22, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 22, tzinfo=tzutc()),
#  datetime.datetime(2022, 8, 16, 14, 20, 23, tzinfo=tzutc())]

# %% [markdown]
# ### 4. For the objects, upload this metadata in a JSON file. (Zu den Objekten, noch diese Metadaten in einem JSON-File hochladen.) The name of the JSON file can correspond to the object ID.

# %%
def make_json(list_objectID, list_QRcode_data, list_timestamp):
    if not os.path.exists(PATH + os.sep + 'metadata'):
        os.makedirs('metadata')
    for i in range(len(list_objectID)):
        dictionary = {
            "ObjectID": list_objectID[i],
            "QRcode_data": list_QRcode_data[i],
            "Timestamp": list_timestamp[i],
        }
        json_object = json.dumps(dictionary, sort_keys=True, default=str)
        with open(f'metadata/{list_objectID[i]}.json', 'w') as outfile:
            outfile.write(json_object)

# %%
make_json(list_objectID, list_QRcode_data, list_timestamp)

# %% [markdown]
# ### 5. Upload json files to S3

# %%
def upload_metadata(subfolder_path): 
    s3 = boto3.client('s3')
    s3.put_object(Bucket=bucket.name, Body='', Key=(f'{subfolder_path}')) # create directory 
    for file in os.listdir('metadata'):
        s3.upload_file(f'metadata/{file}', bucket.name, f'{subfolder_path}{file}')

# %%
upload_metadata('attila/metadata/')
